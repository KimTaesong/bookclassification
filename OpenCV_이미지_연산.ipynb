# %% [markdown]
# <a href="https://colab.research.google.com/github/KimTaesong/bookclassification/blob/master/OpenCV_%EC%9D%B4%EB%AF%B8%EC%A7%80_%EC%97%B0%EC%82%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## OpenCV 이미지 연산
# [강의 노트](https://github.com/ndb796/Python-Data-Analysis-and-Image-Processing-Tutorial/blob/master/07.%20OpenCV%20%EC%9D%B4%EB%AF%B8%EC%A7%80%20%EC%97%B0%EC%82%B0/Python%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EB%B6%84%EC%84%9D%EA%B3%BC%20%EC%9D%B4%EB%AF%B8%EC%A7%80%20%EC%B2%98%EB%A6%AC%20-%20OpenCV%20%EC%9D%B4%EB%AF%B8%EC%A7%80%20%EC%97%B0%EC%82%B0.pdf)

# %% [markdown]
# CoLab에서 파일을 업로드하는 방법은 다음과 같습니다.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7ae6ff0f-a63c-455e-aafe-f6e89c501592" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ae6ff0f-a63c-455e-aafe-f6e89c501592">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dog.jpg to dog.jpg

# %% [markdown]
# OpenCV를 활용한 이미지 크기 및 픽셀 정보 확인

# %%
import cv2
image = cv2.imread('dog.jpg')

# 픽셀 수 및 이미지 크기 확인
print(image.shape)
print(image.size)

# 이미지 Numpy 객체의 특정 픽셀을 가리킵니다.
px = image[100, 100]

# B, G, R 순서로 출력됩니다.
# (단, Gray Scale인 경우에는 B, G, R로 구분되지 않습니다.)
print(px)

# R 값만 출력하기
print(px[2])
# Out:
# (123, 181, 3)
# 66789
# [138 114 202]
# 202

# %% [markdown]
# OpenCV를 활용한 특정 범위 픽셀 변경

# %%
import cv2
import matplotlib.pyplot as plt
import time

image = cv2.imread('dog.jpg')

start_time = time.time()
for i in range(0, 100):
    for j in range(0, 100):
        image[i, j] = [255, 255, 255]
print("--- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
image[0:100, 0:100] = [0, 0, 0]
print("--- %s seconds ---" % (time.time() - start_time))

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# --- 0.013448476791381836 seconds ---
# --- 0.0003829002380371094 seconds ---

# %% [markdown]
# OpenCV를 활용한 ROI(Region of Interest: 관심 있는 영역) 추출

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('dog.jpg')

# Numpy Slicing: ROI 처리 가능
roi = image[0:10, 0:10]

# ROI 단위로 이미지 복사하기
image[0:10, 0:10] = roi

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# OpenCV를 활용한 픽셀별 색상 다루기

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('dog.jpg')
image[:, :, 2] = 0

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
